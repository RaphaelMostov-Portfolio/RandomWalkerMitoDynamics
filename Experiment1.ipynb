# %%
import Random_Walker_Module as rwm
import os
import networkx as nx # I dont think this package is on google colab, might be better to use NetworkX
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# Load graphs from Data Set

# %%
df = pd.read_csv('../Data/MitoTable.csv') 
df.Type = df.Type.astype("category")
df.Type.cat.reorder_categories(["WT", "WTFIX",'DD', 'DDFIX'], inplace=True)
print(df.shape)
#df = df.loc[(df.Date.isin([24]))&(df.Type.isin(['WT','DDFIX']))]
df = df.loc[(df.Date.isin([24]))&(df.Type.isin(['WT']))]
df.Type = df.Type.cat.remove_unused_categories()
print(df.shape)
graphs = []
for index in tqdm(df.index):      
    # Load the graph
    fname = os.path.join('../Data/',df.Name[index]+'.gnet') 
    graph_list = pd.read_csv(fname, skiprows=1, sep='\t', header=None)
    graph_list.columns = ['Source','Target','Length']
    edges = [(i,j) for i,j in zip(graph_list.Source.values,graph_list.Target.values)]
    g = nx.from_edgelist(edges, create_using = nx.MultiGraph) # this is the variable that stores the mitochondria graph
    graphs.append(g)
# Out:
# (3606, 8)
# (351, 8)
# C:\Users\mosto\AppData\Local\Temp\ipykernel_1736\2977001957.py:3: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   df.Type.cat.reorder_categories(["WT", "WTFIX",'DD', 'DDFIX'], inplace=True)
# C:\Users\mosto\AppData\Local\Temp\ipykernel_1736\2977001957.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index in tqdm(df.index):
#   0%|          | 0/351 [00:00<?, ?it/s]

# %% [markdown]
# Compute test statistic for graphs in data set

# %%
#get the valid mitochondria graphs from the data set
def is_valid_mitograph(g):
    degree_view = nx.degree(g)
    num_deg_1 = sum(1 for node, degree in degree_view if degree == 1)
    num_deg_3 = sum(1 for node, degree in degree_view if degree == 3)
    return nx.is_planar(g) and num_deg_1+num_deg_3==g.number_of_nodes()

obs_graphs = [g for g in graphs if is_valid_mitograph(g)]
S = len(obs_graphs)
print('The data set for wild type mitochondria contains', S, 'valid mitographs out of', len(graphs), 'samples')

# Compute T_0
def compute_degree_ratio(g):
    degree_view = nx.degree(g)
    num_deg_3 = sum(1 for node, degree in degree_view if degree == 3)
    return num_deg_3/g.number_of_nodes()
obs_deg_ratios = []
for g in obs_graphs:
    r = compute_degree_ratio(g)
    obs_deg_ratios.append(r)
T_0 = np.average(obs_deg_ratios)


N_max = 0
for g in obs_graphs:
    if nx.number_of_nodes(g)>N_max: N_max = nx.number_of_nodes(g)

print('Our T_0 value is:', T_0)
# Out:
# The data set for wild type mitochondria contains 55 valid mitographs out of 351 samples
# Our T_0 value is: 0.5488619131643031

# %% [markdown]
# Simulate data sets

# %%
def simulate_data_set(S, initial_walk_length):
    num_time_steps = initial_walk_length+S
    initial_state = rwm.load_i_tubule()
    path, num_fails = rwm.random_walk(initial_state,num_time_steps)
    
    sim_deg_ratios = []
    for n in range(initial_walk_length,num_time_steps):
        graph = path[n]
        sim_deg_ratios.append(rwm.Mitograph.compute_degree_ratio(graph))

    return np.average(sim_deg_ratios), num_fails

def run_experiment(M, walk_length):
    total_fails = 0
    T_values = []
    for _ in range(M):
        T, num_fails = simulate_data_set(S, walk_length)
        print('T:', T, 'number of attempts to complete walk:', num_fails+1)
        T_values.append(T)
        total_fails = total_fails+num_fails
    print('failure rate: ',  100*(total_fails/(M+total_fails)),'%')
    return T_values

rwm.N_max = round(1.05*N_max)
walk_length = rwm.N_max
print('Maximum number of nodes:', rwm.N_max)
print('Walk length:', walk_length)
M = 100
T_values = run_experiment(M,walk_length)
# Out:
# Maximum number of nodes: 55
# Walk length: 55
# T: 0.8948680393680395 number of attempts to complete walk: 1
# T: 0.9149665889665889 number of attempts to complete walk: 1
# T: 0.8829921780020594 number of attempts to complete walk: 1
# T: 0.8756152738346414 number of attempts to complete walk: 1
# T: 0.9240352240352241 number of attempts to complete walk: 1
# T: 0.8792499352499352 number of attempts to complete walk: 1
# T: 0.906904687904688 number of attempts to complete walk: 1
# T: 0.9042230135550294 number of attempts to complete walk: 1
# T: 0.8498186998186998 number of attempts to complete walk: 1
# T: 0.9024599844599844 number of attempts to complete walk: 1
# T: 0.9098159803159802 number of attempts to complete walk: 1
# T: 0.9076673141673142 number of attempts to complete walk: 1
# T: 0.9069309764309764 number of attempts to complete walk: 1
# T: 0.9424182966791662 number of attempts to complete walk: 1
# T: 0.9171717171717172 number of attempts to complete walk: 1
# T: 0.8903133903133902 number of attempts to complete walk: 1
# T: 0.8625771933380628 number of attempts to complete walk: 1
# T: 0.9037529137529138 number of attempts to complete walk: 1
# T: 0.8973596218596219 number of attempts to complete walk: 1
# T: 0.8936443618597769 number of attempts to complete walk: 1
# T: 0.8522663607801948 number of attempts to complete walk: 1
# T: 0.9436695156695156 number of attempts to complete walk: 1
# T: 0.9067340067340068 number of attempts to complete walk: 1
# T: 0.8966423206423206 number of attempts to complete walk: 1
# T: 0.8908391270565185 number of attempts to complete walk: 1
# T: 0.918078218078218 number of attempts to complete walk: 1
# T: 0.88071851176199 number of attempts to complete walk: 1
# T: 0.8709149891975979 number of attempts to complete walk: 1
# T: 0.8893680393680393 number of attempts to complete walk: 1
# T: 0.8991097316532098 number of attempts to complete walk: 2
# T: 0.9119075036367527 number of attempts to complete walk: 1
# T: 0.9303030303030303 number of attempts to complete walk: 1
# T: 0.9178685573685573 number of attempts to complete walk: 1
# T: 0.9313131313131313 number of attempts to complete walk: 1
# T: 0.8731966439357745 number of attempts to complete walk: 2
# T: 0.898873348873349 number of attempts to complete walk: 2
# T: 0.9264698264698266 number of attempts to complete walk: 1
# T: 0.855589937364641 number of attempts to complete walk: 1
# T: 0.8925770520651944 number of attempts to complete walk: 1
# T: 0.889361926318448 number of attempts to complete walk: 1
# T: 0.9159140119140119 number of attempts to complete walk: 1
# T: 0.9114813519813519 number of attempts to complete walk: 1
# T: 0.9205387205387207 number of attempts to complete walk: 1
# T: 0.9020564620564621 number of attempts to complete walk: 2
# T: 0.8984853664853665 number of attempts to complete walk: 1
# T: 0.8757472572077316 number of attempts to complete walk: 1
# T: 0.9284659414659414 number of attempts to complete walk: 1
# T: 0.9046832426832426 number of attempts to complete walk: 1
# T: 0.9235690235690237 number of attempts to complete walk: 1
# T: 0.9038641543641543 number of attempts to complete walk: 1
# T: 0.877013209013209 number of attempts to complete walk: 1
# T: 0.9116032116032114 number of attempts to complete walk: 1
# T: 0.8208512156120851 number of attempts to complete walk: 1
# T: 0.9252789432789432 number of attempts to complete walk: 1
# T: 0.9169386169386169 number of attempts to complete walk: 1
# T: 0.8957803677803678 number of attempts to complete walk: 1
# T: 0.895959595959596 number of attempts to complete walk: 1
# T: 0.8336369604630474 number of attempts to complete walk: 1
# T: 0.9004144004144005 number of attempts to complete walk: 1
# T: 0.908974263256872 number of attempts to complete walk: 1
# T: 0.9468013468013469 number of attempts to complete walk: 1
# T: 0.9148272468272468 number of attempts to complete walk: 2
# T: 0.9175084175084175 number of attempts to complete walk: 1
# T: 0.8488100233100234 number of attempts to complete walk: 1
# T: 0.9286583786583786 number of attempts to complete walk: 1
# T: 0.9592592592592593 number of attempts to complete walk: 1
# T: 0.9134467754467753 number of attempts to complete walk: 1
# T: 0.9355348355348356 number of attempts to complete walk: 1
# T: 0.9027692307692308 number of attempts to complete walk: 1
# T: 0.8527140299314212 number of attempts to complete walk: 1
# T: 0.9298114478114478 number of attempts to complete walk: 1
# T: 0.9447811447811447 number of attempts to complete walk: 1
# T: 0.9518518518518517 number of attempts to complete walk: 2
# T: 0.8907655827557014 number of attempts to complete walk: 1
# T: 0.8769943607117521 number of attempts to complete walk: 1
# T: 0.8330727930391961 number of attempts to complete walk: 1
# T: 0.8764605024605024 number of attempts to complete walk: 1
# T: 0.8622076787946352 number of attempts to complete walk: 1
# T: 0.9105024605024605 number of attempts to complete walk: 1
# T: 0.9120555555555556 number of attempts to complete walk: 1
# T: 0.8636099456099454 number of attempts to complete walk: 1
# T: 0.9014726754726754 number of attempts to complete walk: 1
# T: 0.9162631442631443 number of attempts to complete walk: 1
# T: 0.8863458554328119 number of attempts to complete walk: 1
# T: 0.8672895622895623 number of attempts to complete walk: 2
# T: 0.8860191315784203 number of attempts to complete walk: 1
# T: 0.942087542087542 number of attempts to complete walk: 1
# T: 0.9494949494949494 number of attempts to complete walk: 2
# T: 0.9339668479668479 number of attempts to complete walk: 1
# T: 0.9139471639471639 number of attempts to complete walk: 1
# T: 0.9265993265993265 number of attempts to complete walk: 1
# T: 0.8861693861693861 number of attempts to complete walk: 1
# T: 0.9226480186480186 number of attempts to complete walk: 1
# T: 0.9515151515151514 number of attempts to complete walk: 1
# T: 0.86450259000259 number of attempts to complete walk: 1
# T: 0.8512820512820513 number of attempts to complete walk: 1
# T: 0.8756410256410256 number of attempts to complete walk: 1
# T: 0.9212898212898213 number of attempts to complete walk: 1
# T: 0.8657069401832248 number of attempts to complete walk: 1
# T: 0.8990854557534399 number of attempts to complete walk: 1
# failure rate:  7.4074074074074066 %

# %% [markdown]
# Compute P-value, this is a right tailed test, as completely triangulated graphs are unlikely

# %%
right_p_value = sum(1 for T in T_values if T>=T_0)/M
left_p_value = sum(1 for T in T_values if T<=T_0)/M
print('right p_val:', right_p_value, 'left p_val:', left_p_value)
# Out:
# right p_val: 1.0 left p_val: 0.0

# %% [markdown]
# Running experiment again but without restricting the total number of nodes:

# %%
rwm.N_max = float('inf') #the module is programmed so that setting N_max to this value removes the restriction
T_values = run_experiment(M,walk_length)
p_value = sum(1 for T in T_values if T>=T_0)/M
print('p_val:', p_value)
# Out:
# T: 0.7568565545759421 number of attempts to complete walk: 1
# T: 0.6709444819504353 number of attempts to complete walk: 1
# T: 0.669982716594551 number of attempts to complete walk: 1
# T: 0.7245336343090245 number of attempts to complete walk: 1
# T: 0.7286208397932589 number of attempts to complete walk: 1
# T: 0.7657013050283813 number of attempts to complete walk: 1
# T: 0.6780085932151534 number of attempts to complete walk: 1
# T: 0.7601529967536963 number of attempts to complete walk: 1
# T: 0.7463996824200742 number of attempts to complete walk: 1
# T: 0.7022467075459663 number of attempts to complete walk: 1
# T: 0.7149169854696762 number of attempts to complete walk: 1
# T: 0.6441084362247621 number of attempts to complete walk: 1
# T: 0.7163480480647458 number of attempts to complete walk: 1
# T: 0.7231648929921943 number of attempts to complete walk: 1
# T: 0.7054974936950374 number of attempts to complete walk: 1
# T: 0.6758957499667315 number of attempts to complete walk: 1
# T: 0.6614218076379651 number of attempts to complete walk: 1
# T: 0.756414849899613 number of attempts to complete walk: 1
# T: 0.669117477073046 number of attempts to complete walk: 1
# T: 0.7063502315364649 number of attempts to complete walk: 1
# T: 0.7644589935069939 number of attempts to complete walk: 1
# T: 0.6813937265207309 number of attempts to complete walk: 1
# T: 0.6951524521295885 number of attempts to complete walk: 1
# T: 0.7042842211216332 number of attempts to complete walk: 1
# T: 0.7407574814762812 number of attempts to complete walk: 1
# T: 0.7569079581114857 number of attempts to complete walk: 1
# T: 0.7253991993796528 number of attempts to complete walk: 1
# T: 0.755061447288832 number of attempts to complete walk: 1
# T: 0.7085688691140818 number of attempts to complete walk: 1
# T: 0.681100000510198 number of attempts to complete walk: 1
# T: 0.7129732040571306 number of attempts to complete walk: 1
# T: 0.728832830755611 number of attempts to complete walk: 1
# T: 0.7355159736989496 number of attempts to complete walk: 1
# T: 0.7269541958331446 number of attempts to complete walk: 1
# T: 0.7038368438072129 number of attempts to complete walk: 1
# T: 0.7194632106425075 number of attempts to complete walk: 1
# T: 0.767606465471054 number of attempts to complete walk: 1
# T: 0.7127611365803885 number of attempts to complete walk: 1
# T: 0.7098865741098193 number of attempts to complete walk: 1
# T: 0.7265763466996239 number of attempts to complete walk: 1
# T: 0.6650843587332034 number of attempts to complete walk: 1
# T: 0.7671912082116281 number of attempts to complete walk: 1
# T: 0.7477239210119667 number of attempts to complete walk: 1
# T: 0.7146628867756639 number of attempts to complete walk: 1
# T: 0.7359359785208189 number of attempts to complete walk: 1
# T: 0.6858415504870492 number of attempts to complete walk: 1
# T: 0.6947283988378549 number of attempts to complete walk: 1
# T: 0.7130163858608514 number of attempts to complete walk: 1
# T: 0.6678998782061301 number of attempts to complete walk: 1
# T: 0.6958420277073462 number of attempts to complete walk: 1
# T: 0.7229149622409796 number of attempts to complete walk: 1
# T: 0.711397380398288 number of attempts to complete walk: 1
# T: 0.7575833295754587 number of attempts to complete walk: 1
# T: 0.7062248233709303 number of attempts to complete walk: 1
# T: 0.6914220482420604 number of attempts to complete walk: 1
# T: 0.666272423865418 number of attempts to complete walk: 1
# T: 0.6774859906244605 number of attempts to complete walk: 1
# T: 0.6615193856361461 number of attempts to complete walk: 1
# T: 0.7438481824610353 number of attempts to complete walk: 1
# T: 0.6328133822325273 number of attempts to complete walk: 1
# T: 0.6621113885692905 number of attempts to complete walk: 1
# T: 0.706498535596228 number of attempts to complete walk: 1
# T: 0.6624852311492436 number of attempts to complete walk: 1
# T: 0.7211018982680141 number of attempts to complete walk: 1
# T: 0.7504421349145174 number of attempts to complete walk: 1
# T: 0.711503050912245 number of attempts to complete walk: 1
# T: 0.7862206169267135 number of attempts to complete walk: 1
# T: 0.6815376544327411 number of attempts to complete walk: 1
# T: 0.715239601527935 number of attempts to complete walk: 1
# T: 0.7033065558122253 number of attempts to complete walk: 1
# T: 0.6592805049845262 number of attempts to complete walk: 1
# T: 0.7440532551772955 number of attempts to complete walk: 1
# T: 0.7848179064400757 number of attempts to complete walk: 1
# T: 0.7118098816262407 number of attempts to complete walk: 1
# T: 0.6320448020147098 number of attempts to complete walk: 1
# T: 0.7221707656407569 number of attempts to complete walk: 1
# T: 0.7372267051633056 number of attempts to complete walk: 1
# T: 0.6862326704651202 number of attempts to complete walk: 1
# T: 0.7281587736265036 number of attempts to complete walk: 1
# T: 0.75030816642714 number of attempts to complete walk: 1
# T: 0.704124224579254 number of attempts to complete walk: 1
# T: 0.7266364402034716 number of attempts to complete walk: 1
# T: 0.6975999219977552 number of attempts to complete walk: 1
# T: 0.6953591248980323 number of attempts to complete walk: 1
# T: 0.7790776132818179 number of attempts to complete walk: 1
# T: 0.7267369187794607 number of attempts to complete walk: 1
# T: 0.7405801117138282 number of attempts to complete walk: 1
# T: 0.7247685741676915 number of attempts to complete walk: 1
# T: 0.7757818430447945 number of attempts to complete walk: 1
# T: 0.6528052170441533 number of attempts to complete walk: 1
# T: 0.7681353735169781 number of attempts to complete walk: 1
# T: 0.7394425148554506 number of attempts to complete walk: 1
# T: 0.7910702694424881 number of attempts to complete walk: 1
# T: 0.7370729220540502 number of attempts to complete walk: 1
# T: 0.7671174578738257 number of attempts to complete walk: 1
# T: 0.7198108282267951 number of attempts to complete walk: 1
# T: 0.7410330305572878 number of attempts to complete walk: 1
# T: 0.7661144178793671 number of attempts to complete walk: 1
# T: 0.6793092165765929 number of attempts to complete walk: 1
# T: 0.717381854225964 number of attempts to complete walk: 1
# failure rate:  0.0 %
# p_val: 1.0

# %% [markdown]
# Running experiment again, but this time restricting the amount of degree 3 nodes

# %%
rwm.n_max = 32 #this places a restriction on the number of degree 3 nodes
T_values = run_experiment(M,walk_length)
p_value = sum(1 for T in T_values if T>=T_0)/M
print('p_val:', p_value)
# Out:
# T: 0.6259175125708625 number of attempts to complete walk: 1
# T: 0.788806289371614 number of attempts to complete walk: 1
# T: 0.7440395384362156 number of attempts to complete walk: 1
# T: 0.7262321630933869 number of attempts to complete walk: 1
# T: 0.7293880550385298 number of attempts to complete walk: 1
# T: 0.7418460091495805 number of attempts to complete walk: 1
# T: 0.7019130333113375 number of attempts to complete walk: 1
# T: 0.767655610228854 number of attempts to complete walk: 1
# T: 0.742888596323307 number of attempts to complete walk: 1
# T: 0.7195067087697732 number of attempts to complete walk: 1
# T: 0.7064066335645816 number of attempts to complete walk: 1
# T: 0.7369954403557551 number of attempts to complete walk: 1
# T: 0.6739056038856436 number of attempts to complete walk: 1
# T: 0.7207222374614927 number of attempts to complete walk: 1
# T: 0.7484097582360765 number of attempts to complete walk: 1
# T: 0.7050529390681839 number of attempts to complete walk: 1
# T: 0.6898388745358303 number of attempts to complete walk: 2
# T: 0.7756900582501322 number of attempts to complete walk: 1
# T: 0.7090752991673193 number of attempts to complete walk: 1
# T: 0.6982053393155244 number of attempts to complete walk: 1
# T: 0.6866037112015289 number of attempts to complete walk: 1
# T: 0.6789808610819648 number of attempts to complete walk: 1
# T: 0.7155222405006408 number of attempts to complete walk: 1
# T: 0.6920751986369617 number of attempts to complete walk: 1
# T: 0.7006912658471723 number of attempts to complete walk: 1
# T: 0.7516050062368211 number of attempts to complete walk: 1
# T: 0.7427238241145492 number of attempts to complete walk: 1
# T: 0.6614031128026188 number of attempts to complete walk: 1
# T: 0.7445686076611874 number of attempts to complete walk: 1
# T: 0.7181747876884603 number of attempts to complete walk: 1
# T: 0.6951356462928521 number of attempts to complete walk: 1
# T: 0.748964786752428 number of attempts to complete walk: 1
# T: 0.6839580461454806 number of attempts to complete walk: 1
# T: 0.6656883381674814 number of attempts to complete walk: 1
# T: 0.8458052392504622 number of attempts to complete walk: 1
# T: 0.653484396629003 number of attempts to complete walk: 1
# T: 0.7322929659173056 number of attempts to complete walk: 1
# T: 0.6914553755696264 number of attempts to complete walk: 1
# T: 0.7342258270960779 number of attempts to complete walk: 1
# T: 0.7226003985561121 number of attempts to complete walk: 1
# T: 0.7600362052908879 number of attempts to complete walk: 1
# T: 0.6640066501746249 number of attempts to complete walk: 1
# T: 0.7269602237217169 number of attempts to complete walk: 1
# T: 0.6783968724243336 number of attempts to complete walk: 1
# T: 0.6997692861726346 number of attempts to complete walk: 1
# T: 0.6649881639177219 number of attempts to complete walk: 1
# T: 0.7158571205717784 number of attempts to complete walk: 1
# T: 0.7084665174231197 number of attempts to complete walk: 1
# T: 0.6864877126084826 number of attempts to complete walk: 1
# T: 0.6599063805210332 number of attempts to complete walk: 1
# T: 0.6902519117781231 number of attempts to complete walk: 1
# T: 0.7439263161433878 number of attempts to complete walk: 1
# T: 0.7387128080023405 number of attempts to complete walk: 1
# T: 0.7285103479356562 number of attempts to complete walk: 1
# T: 0.6844704050273737 number of attempts to complete walk: 1
# T: 0.757382869146705 number of attempts to complete walk: 1
# T: 0.7174886364524098 number of attempts to complete walk: 1
# T: 0.7387313625540144 number of attempts to complete walk: 1
# T: 0.765877645315489 number of attempts to complete walk: 1
# T: 0.772391523406489 number of attempts to complete walk: 1
# T: 0.7513889912367051 number of attempts to complete walk: 1
# T: 0.7420473954775834 number of attempts to complete walk: 1
# T: 0.7105120096069725 number of attempts to complete walk: 1
# T: 0.6731141910752304 number of attempts to complete walk: 1
# T: 0.6882936220232649 number of attempts to complete walk: 1
# T: 0.7382526673953903 number of attempts to complete walk: 1
# T: 0.6666694927158816 number of attempts to complete walk: 1
# T: 0.7294320788174854 number of attempts to complete walk: 1
# T: 0.7233191185643423 number of attempts to complete walk: 1
# T: 0.6650837232005035 number of attempts to complete walk: 1
# T: 0.7431454837997468 number of attempts to complete walk: 1
# T: 0.699659623895589 number of attempts to complete walk: 1
# T: 0.7035812697271601 number of attempts to complete walk: 1
# T: 0.7254345373251242 number of attempts to complete walk: 1
# T: 0.7646798210335207 number of attempts to complete walk: 1
# T: 0.7534012448048 number of attempts to complete walk: 1
# T: 0.761775048486469 number of attempts to complete walk: 1
# T: 0.692090096899917 number of attempts to complete walk: 1
# T: 0.6974239695285892 number of attempts to complete walk: 1
# T: 0.7074826410674554 number of attempts to complete walk: 1
# T: 0.7302513862768715 number of attempts to complete walk: 1
# T: 0.753157413603673 number of attempts to complete walk: 1
# T: 0.7005298795470368 number of attempts to complete walk: 1
# T: 0.681474672469749 number of attempts to complete walk: 1
# T: 0.7046751990445212 number of attempts to complete walk: 1
# T: 0.672793100760227 number of attempts to complete walk: 1
# T: 0.7300181728650951 number of attempts to complete walk: 1
# T: 0.6893511141132926 number of attempts to complete walk: 1
# T: 0.7217988548015516 number of attempts to complete walk: 1
# T: 0.7221156133382342 number of attempts to complete walk: 1
# T: 0.7609457173539367 number of attempts to complete walk: 1
# T: 0.7011297974902475 number of attempts to complete walk: 1
# T: 0.7130122444785785 number of attempts to complete walk: 1
# T: 0.6942445539465585 number of attempts to complete walk: 1
# T: 0.6908991003665819 number of attempts to complete walk: 1
# T: 0.7041337148609426 number of attempts to complete walk: 1
# T: 0.6613474192731745 number of attempts to complete walk: 1
# T: 0.7408200240644154 number of attempts to complete walk: 1
# T: 0.7296680919791564 number of attempts to complete walk: 1
# T: 0.7800444730618256 number of attempts to complete walk: 1
# failure rate:  0.9900990099009901 %
# p_val: 1.0
